# %% [markdown]
# Preprocessing of images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

file_location = "/home/syedjafer/Documents/Handwriting_recognition_svm/test1/images/aaa.png"
img = cv2.imread(file_location,0)
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()


cv2.imwrite("res.png",thresh1)
# Out:
# True

# %%
import glob 
image_location = "/home/syedjafer/Documents/Handwriting_recognition_svm/test1/images/"
folder_depth = 8 

image_x = []
image_y = []
files = []

# to get list of files in the current directory
for level in range(folder_depth):
    folder = chr(ord("a")+level)
    print (image_location+folder+"/")
    label_len = len(glob.glob(image_location+folder+"/"+"*.png"))
    files = files + glob.glob(image_location+folder+"/"+"*.png")
    print(files)

for file in files:
    img = cv2.imread(file,0)
    ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
    resized_image = cv2.resize(thresh1, (100, 100))
    cv2.imwrite(file,resized_image)
# Out:
# /home/syedjafer/Documents/Handwriting_recognition_svm/test1/images/a/
# ...
