# %%
#imports
import cv2
import os
import random
import matplotlib.pylab as plt
import glob
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# knowing shapes of my image
files = glob.glob("*.png")
for file in files:
    image = cv2.imread(file)
#     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     print ("shape of image ",gray.shape)
    resized_image = cv2.resize(image, (100, 100))
    filename = file
    cv2.imwrite(file, resized_image)

# %%
ls
# Out:
#  a_00.png   a_07.png   a_14.png   a_21.png
#  a_01.png   a_08.png   a_15.png  'images to numpy arrays .ipynb'
#  a_02.png   a_09.png   a_16.png   svm_handwriting.ipynb
#  a_03.png   a_10.png   a_17.png   Untitled.ipynb
#  a_04.png   a_11.png   a_18.png   x_images_arrays.npz
#  a_05.png   a_12.png   a_19.png   y_infiltration_labels.npz
#  a_06.png   a_13.png   a_20.png

# %%
files = glob.glob("*.png")
for file in files:
    image = cv2.imread(file)
    print ("shape ", image.shape)
# Out:
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)
# shape  (200, 200, 3)

# %%
train_files = []
y_train = []
i=0
for _file in files:
    train_files.append(_file)
    y_train.append("a")
print("Files in train_files: %d" % len(train_files))
# Out:
# Files in train_files: 22

# %%
from scipy import ndimage
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img


image_width = 200
image_height = 200
ratio = 4

image_width = int(image_width / ratio)
image_height = int(image_height / ratio)

channels = 3
nb_classes = 1

i = 0
for _file in train_files:
    img = load_img(_file)  # this is a PIL image
    img.thumbnail((image_width, image_height))
    # Convert to Numpy Array
    x = img_to_array(img)

# %%
new_x = []
new_y = []
files = glob.glob("*.png")
for file in files:
    image = cv2.imread(file)
    new_x.append(image)
    new_y.append("a")

# %%
print (new_x)
print (new_y)
# Out:
# [array([[[232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [231, 231, 231]],
#
#        [[232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [233, 233, 233],
#         [233, 233, 233],
#         [234, 234, 234]],
#
#        [[232, 232, 232],
#         [232, 232, 232],
#         [231, 231, 231],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        ...,
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [231, 231, 231],
#         ...,
#         [230, 230, 230],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [231, 231, 231],
#         [230, 230, 230],
#         [229, 229, 229]]], dtype=uint8), array([[[228, 228, 228],
#         [229, 229, 229],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [229, 229, 229]],
#
#        [[229, 229, 229],
#         [227, 227, 227],
#         [227, 227, 227],
#         ...,
#         [232, 232, 232],
#         [232, 232, 232],
#         [231, 231, 231]],
#
#        [[230, 230, 230],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [231, 231, 231]],
#
#        ...,
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [232, 232, 232],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [230, 230, 230]],
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [228, 228, 228],
#         [229, 229, 229],
#         [230, 230, 230]]], dtype=uint8), array([[[231, 231, 231],
#         [230, 230, 230],
#         [229, 229, 229],
#         ...,
#         [233, 233, 233],
#         [234, 234, 234],
#         [234, 234, 234]],
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [229, 229, 229],
#         ...,
#         [235, 235, 235],
#         [236, 236, 236],
#         [235, 235, 235]],
#
#        [[229, 229, 229],
#         [228, 228, 228],
#         [228, 228, 228],
#         ...,
#         [235, 235, 235],
#         [236, 236, 236],
#         [235, 235, 235]],
#
#        ...,
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [231, 231, 231],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [231, 231, 231],
#         ...,
#         [232, 232, 232],
#         [233, 233, 233],
#         [230, 230, 230]],
#
#        [[229, 229, 229],
#         [230, 230, 230],
#         [230, 230, 230],
#         ...,
#         [232, 232, 232],
#         [232, 232, 232],
#         [231, 231, 231]]], dtype=uint8), array([[[234, 234, 234],
#         [233, 233, 233],
#         [233, 233, 233],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[233, 233, 233],
#         [232, 232, 232],
#         [233, 233, 233],
#         ...,
#         [232, 232, 232],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[232, 232, 232],
#         [233, 233, 233],
#         [234, 234, 234],
#         ...,
#         [233, 233, 233],
#         [232, 232, 232],
#         [229, 229, 229]],
#
#        ...,
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [229, 229, 229],
#         [228, 228, 228]],
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [232, 232, 232],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230]],
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [230, 230, 230],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [228, 228, 228]]], dtype=uint8), array([[[232, 232, 232],
#         [230, 230, 230],
#         [229, 229, 229],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        [[231, 231, 231],
#         [230, 230, 230],
#         [230, 230, 230],
#         ...,
#         [232, 232, 232],
#         [232, 232, 232],
#         [233, 233, 233]],
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [233, 233, 233],
#         [233, 233, 233],
#         [233, 233, 233]],
#
#        ...,
#
#        [[229, 229, 229],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [230, 230, 230],
#         [233, 233, 233],
#         [231, 231, 231]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [230, 230, 230],
#         [232, 232, 232],
#         [232, 232, 232]],
#
#        [[232, 232, 232],
#         [230, 230, 230],
#         [229, 229, 229],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]]], dtype=uint8), array([[[226, 226, 226],
#         [227, 227, 227],
#         [229, 229, 229],
#         ...,
#         [228, 228, 228],
#         [229, 229, 229],
#         [231, 231, 231]],
#
#        [[227, 227, 227],
#         [227, 227, 227],
#         [228, 228, 228],
#         ...,
#         [229, 229, 229],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        [[226, 226, 226],
#         [226, 226, 226],
#         [226, 226, 226],
#         ...,
#         [230, 230, 230],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        ...,
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [228, 228, 228],
#         ...,
#         [224, 224, 224],
#         [226, 226, 226],
#         [228, 228, 228]],
#
#        [[226, 226, 226],
#         [228, 228, 228],
#         [227, 227, 227],
#         ...,
#         [228, 228, 228],
#         [230, 230, 230],
#         [229, 229, 229]],
#
#        [[225, 225, 225],
#         [228, 228, 228],
#         [227, 227, 227],
#         ...,
#         [226, 226, 226],
#         [227, 227, 227],
#         [227, 227, 227]]], dtype=uint8), array([[[225, 225, 225],
#         [227, 227, 227],
#         [229, 229, 229],
#         ...,
#         [228, 228, 228],
#         [229, 229, 229],
#         [228, 228, 228]],
#
#        [[229, 229, 229],
#         [228, 228, 228],
#         [228, 228, 228],
#         ...,
#         [226, 226, 226],
#         [227, 227, 227],
#         [229, 229, 229]],
#
#        [[226, 226, 226],
#         [227, 227, 227],
#         [228, 228, 228],
#         ...,
#         [224, 224, 224],
#         [225, 225, 225],
#         [227, 227, 227]],
#
#        ...,
#
#        [[230, 230, 230],
#         [229, 229, 229],
#         [228, 228, 228],
#         ...,
#         [229, 229, 229],
#         [230, 230, 230],
#         [231, 231, 231]],
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [231, 231, 231],
#         ...,
#         [228, 228, 228],
#         [230, 230, 230],
#         [231, 231, 231]],
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [232, 232, 232],
#         ...,
#         [230, 230, 230],
#         [229, 229, 229],
#         [228, 228, 228]]], dtype=uint8), array([[[233, 233, 233],
#         [234, 234, 234],
#         [233, 233, 233],
#         ...,
#         [230, 230, 230],
#         [232, 232, 232],
#         [232, 232, 232]],
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [231, 231, 231],
#         [232, 232, 232],
#         [232, 232, 232]],
#
#        [[232, 232, 232],
#         [234, 234, 234],
#         [235, 235, 235],
#         ...,
#         [232, 232, 232],
#         [233, 233, 233],
#         [232, 232, 232]],
#
#        ...,
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [232, 232, 232],
#         ...,
#         [230, 230, 230],
#         [231, 231, 231],
#         [233, 233, 233]],
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [233, 233, 233],
#         ...,
#         [230, 230, 230],
#         [233, 233, 233],
#         [233, 233, 233]],
#
#        [[231, 231, 231],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [232, 232, 232],
#         [231, 231, 231],
#         [231, 231, 231]]], dtype=uint8), array([[[233, 233, 233],
#         [231, 231, 231],
#         [232, 232, 232],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[232, 232, 232],
#         [229, 229, 229],
#         [231, 231, 231],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [230, 230, 230]],
#
#        [[230, 230, 230],
#         [229, 229, 229],
#         [230, 230, 230],
#         ...,
#         [228, 228, 228],
#         [229, 229, 229],
#         [230, 230, 230]],
#
#        ...,
#
#        [[230, 230, 230],
#         [228, 228, 228],
#         [232, 232, 232],
#         ...,
#         [232, 232, 232],
#         [231, 231, 231],
#         [230, 230, 230]],
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230],
#         ...,
#         [232, 232, 232],
#         [230, 230, 230],
#         [230, 230, 230]],
#
#        [[232, 232, 232],
#         [232, 232, 232],
#         [230, 230, 230],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [232, 232, 232]]], dtype=uint8), array([[[232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [234, 234, 234],
#         [232, 232, 232],
#         [231, 231, 231]],
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [230, 230, 230]],
#
#        ...,
#
#        [[233, 233, 233],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232]],
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        [[232, 232, 232],
#         [233, 233, 233],
#         [232, 232, 232],
#         ...,
#         [232, 232, 232],
#         [230, 230, 230],
#         [230, 230, 230]]], dtype=uint8), array([[[225, 225, 225],
#         [222, 222, 222],
#         [227, 227, 227],
#         ...,
#         [232, 232, 232],
#         [231, 231, 231],
#         [230, 230, 230]],
#
#        [[228, 228, 228],
#         [227, 227, 227],
#         [226, 226, 226],
#         ...,
#         [233, 233, 233],
#         [230, 230, 230],
#         [229, 229, 229]],
#
#        [[226, 226, 226],
#         [226, 226, 226],
#         [225, 225, 225],
#         ...,
#         [232, 232, 232],
#         [230, 230, 230],
#         [229, 229, 229]],
#
#        ...,
#
#        [[226, 226, 226],
#         [228, 228, 228],
#         [229, 229, 229],
#         ...,
#         [229, 229, 229],
#         [230, 230, 230],
#         [231, 231, 231]],
#
#        [[227, 227, 227],
#         [230, 230, 230],
#         [231, 231, 231],
#         ...,
#         [230, 230, 230],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[227, 227, 227],
#         [227, 227, 227],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230]]], dtype=uint8), array([[[234, 234, 234],
#         [236, 236, 236],
#         [234, 234, 234],
#         ...,
#         [233, 233, 233],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        [[234, 234, 234],
#         [234, 234, 234],
#         [234, 234, 234],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [233, 233, 233]],
#
#        [[232, 232, 232],
#         [233, 233, 233],
#         [234, 234, 234],
#         ...,
#         [231, 231, 231],
#         [230, 230, 230],
#         [231, 231, 231]],
#
#        ...,
#
#        [[230, 230, 230],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [230, 230, 230],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        [[232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [229, 229, 229],
#         [228, 228, 228],
#         [232, 232, 232]],
#
#        [[230, 230, 230],
#         [232, 232, 232],
#         [233, 233, 233],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [231, 231, 231]]], dtype=uint8), array([[[234, 234, 234],
#         [234, 234, 234],
#         [234, 234, 234],
#         ...,
#         [231, 231, 231],
#         [232, 232, 232],
#         [230, 230, 230]],
#
#        [[235, 235, 235],
#         [234, 234, 234],
#         [232, 232, 232],
#         ...,
#         [232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232]],
#
#        [[232, 232, 232],
#         [233, 233, 233],
#         [235, 235, 235],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [232, 232, 232]],
#
#        ...,
#
#        [[232, 232, 232],
#         [230, 230, 230],
#         [229, 229, 229],
#         ...,
#         [227, 227, 227],
#         [228, 228, 228],
#         [230, 230, 230]],
#
#        [[231, 231, 231],
#         [229, 229, 229],
#         [232, 232, 232],
#         ...,
#         [227, 227, 227],
#         [228, 228, 228],
#         [229, 229, 229]],
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [234, 234, 234],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [226, 226, 226]]], dtype=uint8), array([[[229, 229, 229],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [230, 230, 230],
#         ...,
#         [232, 232, 232],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230]],
#
#        ...,
#
#        [[229, 229, 229],
#         [227, 227, 227],
#         [228, 228, 228],
#         ...,
#         [230, 230, 230],
#         [231, 231, 231],
#         [232, 232, 232]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [230, 230, 230],
#         ...,
#         [229, 229, 229],
#         [230, 230, 230],
#         [232, 232, 232]],
#
#        [[229, 229, 229],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [229, 229, 229],
#         [230, 230, 230],
#         [230, 230, 230]]], dtype=uint8), array([[[227, 227, 227],
#         [225, 225, 225],
#         [224, 224, 224],
#         ...,
#         [230, 230, 230],
#         [229, 229, 229],
#         [230, 230, 230]],
#
#        [[227, 227, 227],
#         [227, 227, 227],
#         [227, 227, 227],
#         ...,
#         [232, 232, 232],
#         [230, 230, 230],
#         [230, 230, 230]],
#
#        [[225, 225, 225],
#         [226, 226, 226],
#         [228, 228, 228],
#         ...,
#         [233, 233, 233],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        ...,
#
#        [[229, 229, 229],
#         [228, 228, 228],
#         [228, 228, 228],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        [[227, 227, 227],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [226, 226, 226],
#         [226, 226, 226],
#         [226, 226, 226]]], dtype=uint8), array([[[228, 228, 228],
#         [229, 229, 229],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230]],
#
#        [[230, 230, 230],
#         [229, 229, 229],
#         [230, 230, 230],
#         ...,
#         [229, 229, 229],
#         [227, 227, 227],
#         [227, 227, 227]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [233, 233, 233],
#         [233, 233, 233],
#         [232, 232, 232]],
#
#        ...,
#
#        [[232, 232, 232],
#         [232, 232, 232],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [231, 231, 231]],
#
#        [[233, 233, 233],
#         [233, 233, 233],
#         [232, 232, 232],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230]],
#
#        [[231, 231, 231],
#         [230, 230, 230],
#         [231, 231, 231],
#         ...,
#         [229, 229, 229],
#         [230, 230, 230],
#         [229, 229, 229]]], dtype=uint8), array([[[234, 234, 234],
#         [232, 232, 232],
#         [231, 231, 231],
#         ...,
#         [227, 227, 227],
#         [226, 226, 226],
#         [226, 226, 226]],
#
#        [[229, 229, 229],
#         [228, 228, 228],
#         [229, 229, 229],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [232, 232, 232]],
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [231, 231, 231],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [227, 227, 227]],
#
#        ...,
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [230, 230, 230],
#         ...,
#         [231, 231, 231],
#         [232, 232, 232],
#         [232, 232, 232]],
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [231, 231, 231],
#         ...,
#         [230, 230, 230],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [229, 229, 229],
#         [231, 231, 231],
#         [231, 231, 231]]], dtype=uint8), array([[[231, 231, 231],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [233, 233, 233],
#         [232, 232, 232],
#         [231, 231, 231]],
#
#        [[229, 229, 229],
#         [232, 232, 232],
#         [230, 230, 230],
#         ...,
#         [232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232]],
#
#        [[229, 229, 229],
#         [231, 231, 231],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        ...,
#
#        [[228, 228, 228],
#         [227, 227, 227],
#         [226, 226, 226],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [230, 230, 230]],
#
#        [[228, 228, 228],
#         [227, 227, 227],
#         [228, 228, 228],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230],
#         ...,
#         [231, 231, 231],
#         [232, 232, 232],
#         [232, 232, 232]]], dtype=uint8), array([[[229, 229, 229],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [233, 233, 233],
#         [232, 232, 232],
#         [231, 231, 231]],
#
#        [[230, 230, 230],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [233, 233, 233],
#         [234, 234, 234],
#         [233, 233, 233]],
#
#        [[229, 229, 229],
#         [230, 230, 230],
#         [231, 231, 231],
#         ...,
#         [231, 231, 231],
#         [233, 233, 233],
#         [233, 233, 233]],
#
#        ...,
#
#        [[231, 231, 231],
#         [230, 230, 230],
#         [229, 229, 229],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [230, 230, 230]],
#
#        [[232, 232, 232],
#         [232, 232, 232],
#         [230, 230, 230],
#         ...,
#         [233, 233, 233],
#         [233, 233, 233],
#         [231, 231, 231]],
#
#        [[231, 231, 231],
#         [230, 230, 230],
#         [231, 231, 231],
#         ...,
#         [232, 232, 232],
#         [232, 232, 232],
#         [233, 233, 233]]], dtype=uint8), array([[[231, 231, 231],
#         [230, 230, 230],
#         [230, 230, 230],
#         ...,
#         [231, 231, 231],
#         [232, 232, 232],
#         [230, 230, 230]],
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [232, 232, 232],
#         ...,
#         [232, 232, 232],
#         [233, 233, 233],
#         [229, 229, 229]],
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232]],
#
#        ...,
#
#        [[230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230],
#         ...,
#         [231, 231, 231],
#         [232, 232, 232],
#         [231, 231, 231]],
#
#        [[232, 232, 232],
#         [232, 232, 232],
#         [229, 229, 229],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [234, 234, 234]],
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [227, 227, 227],
#         ...,
#         [231, 231, 231],
#         [230, 230, 230],
#         [231, 231, 231]]], dtype=uint8), array([[[231, 231, 231],
#         [228, 228, 228],
#         [227, 227, 227],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [233, 233, 233],
#         [230, 230, 230],
#         [230, 230, 230]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [228, 228, 228],
#         ...,
#         [233, 233, 233],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        ...,
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [232, 232, 232],
#         ...,
#         [230, 230, 230],
#         [232, 232, 232],
#         [233, 233, 233]],
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [231, 231, 231],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [231, 231, 231],
#         ...,
#         [232, 232, 232],
#         [231, 231, 231],
#         [231, 231, 231]]], dtype=uint8), array([[[231, 231, 231],
#         [229, 229, 229],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [228, 228, 228]],
#
#        [[227, 227, 227],
#         [227, 227, 227],
#         [228, 228, 228],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [230, 230, 230]],
#
#        [[232, 232, 232],
#         [231, 231, 231],
#         [231, 231, 231],
#         ...,
#         [229, 229, 229],
#         [228, 228, 228],
#         [229, 229, 229]],
#
#        ...,
#
#        [[231, 231, 231],
#         [231, 231, 231],
#         [230, 230, 230],
#         ...,
#         [230, 230, 230],
#         [230, 230, 230],
#         [229, 229, 229]],
#
#        [[229, 229, 229],
#         [230, 230, 230],
#         [231, 231, 231],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[231, 231, 231],
#         [232, 232, 232],
#         [231, 231, 231],
#         ...,
#         [228, 228, 228],
#         [228, 228, 228],
#         [229, 229, 229]]], dtype=uint8)]
# ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']

# %%
from sklearn import svm
clf = svm.SVC(gamma=0.001, C=100)
clf.fit(new_x,new_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e141865a6b6c> in <module>
#       1 from sklearn import svm
#       2 clf = svm.SVC(gamma=0.001, C=100)
# ----> 3 clf.fit(new_x,new_y)
#       4
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     745                     ensure_min_features=ensure_min_features,
#     746                     warn_on_dtype=warn_on_dtype,
# --> 747                     estimator=estimator)
#     748     if multi_output:
#     749         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     563         if not allow_nd and array.ndim >= 3:
#     564             raise ValueError("Found array with dim %d. %s expected <= 2."
# --> 565                              % (array.ndim, estimator_name))
#     566         if force_all_finite:
#     567             _assert_all_finite(array,
#
# ValueError: Found array with dim 4. Estimator expected <= 2.

# %%
_x = np.array(new_x)
print (_x.shape)
_x.reshape(())
# Out:
# (22, 100, 100, 3)

# %%
print (np.array(new_x))
# Out:
# [[[[232 232 232]
#    [232 232 232]
#    [232 232 232]
#    ...
#    [230 230 230]
#    [230 230 230]
#    [231 231 231]]
#
#   [[232 232 232]
#    [232 232 232]
#    [232 232 232]
#    ...
#    [233 233 233]
#    [233 233 233]
#    [234 234 234]]
#
#   [[232 232 232]
#    [232 232 232]
#    [231 231 231]
#    ...
#    [231 231 231]
#    [231 231 231]
#    [232 232 232]]
#
#   ...
#
#   [[230 230 230]
#    [230 230 230]
#    [231 231 231]
#    ...
#    [230 230 230]
#    [231 231 231]
#    [232 232 232]]
#
#   [[230 230 230]
#    [230 230 230]
#    [230 230 230]
#    ...
#    [230 230 230]
#    [231 231 231]
#    [231 231 231]]
#
#   [[229 229 229]
#    [229 229 229]
#    [229 229 229]
#    ...
#    [231 231 231]
#    [230 230 230]
#    [229 229 229]]]
#
#
#  [[[228 228 228]
#    [229 229 229]
#    [230 230 230]
#    ...
#    [230 230 230]
#    [230 230 230]
#    [229 229 229]]
#
#   [[229 229 229]
#    [227 227 227]
#    [227 227 227]
#    ...
#    [232 232 232]
#    [232 232 232]
#    [231 231 231]]
#
#   [[230 230 230]
#    [229 229 229]
#    [229 229 229]
#    ...
#    [230 230 230]
#    [230 230 230]
#    [231 231 231]]
#
#   ...
#
#   [[231 231 231]
#    [232 232 232]
#    [232 232 232]
#    ...
#    [231 231 231]
#    [231 231 231]
#    [231 231 231]]
#
#   [[231 231 231]
#    [231 231 231]
#    [232 232 232]
#    ...
#    [229 229 229]
#    [229 229 229]
#    [230 230 230]]
#
#   [[232 232 232]
#    [231 231 231]
#    [231 231 231]
#    ...
#    [228 228 228]
#    [229 229 229]
#    [230 230 230]]]
#
#
#  [[[231 231 231]
#    [230 230 230]
#    [229 229 229]
#    ...
#    [233 233 233]
#    [234 234 234]
#    [234 234 234]]
#
#   [[230 230 230]
#    [230 230 230]
#    [229 229 229]
#    ...
#    [235 235 235]
#    [236 236 236]
#    [235 235 235]]
#
#   [[229 229 229]
#    [228 228 228]
#    [228 228 228]
#    ...
#    [235 235 235]
#    [236 236 236]
#    [235 235 235]]
#
#   ...
#
#   [[231 231 231]
#    [232 232 232]
#    [231 231 231]
#    ...
#    [229 229 229]
#    [229 229 229]
#    [229 229 229]]
#
#   [[231 231 231]
#    [232 232 232]
#    [231 231 231]
#    ...
#    [232 232 232]
#    [233 233 233]
#    [230 230 230]]
#
#   [[229 229 229]
#    [230 230 230]
#    [230 230 230]
#    ...
#    [232 232 232]
#    [232 232 232]
#    [231 231 231]]]
#
#
#  ...
#
#
#  [[[231 231 231]
#    [230 230 230]
#    [230 230 230]
#    ...
#    [231 231 231]
#    [232 232 232]
#    [230 230 230]]
#
#   [[231 231 231]
#    [231 231 231]
#    [232 232 232]
#    ...
#    [232 232 232]
#    [233 233 233]
#    [229 229 229]]
#
#   [[231 231 231]
#    [232 232 232]
#    [232 232 232]
#    ...
#    [232 232 232]
#    [232 232 232]
#    [232 232 232]]
#
#   ...
#
#   [[230 230 230]
#    [230 230 230]
#    [230 230 230]
#    ...
#    [231 231 231]
#    [232 232 232]
#    [231 231 231]]
#
#   [[232 232 232]
#    [232 232 232]
#    [229 229 229]
#    ...
#    [231 231 231]
#    [231 231 231]
#    [234 234 234]]
#
#   [[231 231 231]
#    [231 231 231]
#    [227 227 227]
#    ...
#    [231 231 231]
#    [230 230 230]
#    [231 231 231]]]
#
#
#  [[[231 231 231]
#    [228 228 228]
#    [227 227 227]
#    ...
#    [229 229 229]
#    [229 229 229]
#    [229 229 229]]
#
#   [[229 229 229]
#    [229 229 229]
#    [229 229 229]
#    ...
#    [233 233 233]
#    [230 230 230]
#    [230 230 230]]
#
#   [[229 229 229]
#    [229 229 229]
#    [228 228 228]
#    ...
#    [233 233 233]
#    [231 231 231]
#    [231 231 231]]
#
#   ...
#
#   [[232 232 232]
#    [231 231 231]
#    [232 232 232]
#    ...
#    [230 230 230]
#    [232 232 232]
#    [233 233 233]]
#
#   [[231 231 231]
#    [232 232 232]
#    [231 231 231]
#    ...
#    [231 231 231]
#    [231 231 231]
#    [231 231 231]]
#
#   [[231 231 231]
#    [232 232 232]
#    [231 231 231]
#    ...
#    [232 232 232]
#    [231 231 231]
#    [231 231 231]]]
#
#
#  [[[231 231 231]
#    [229 229 229]
#    [230 230 230]
#    ...
#    [230 230 230]
#    [230 230 230]
#    [228 228 228]]
#
#   [[227 227 227]
#    [227 227 227]
#    [228 228 228]
#    ...
#    [230 230 230]
#    [230 230 230]
#    [230 230 230]]
#
#   [[232 232 232]
#    [231 231 231]
#    [231 231 231]
#    ...
#    [229 229 229]
#    [228 228 228]
#    [229 229 229]]
#
#   ...
#
#   [[231 231 231]
#    [231 231 231]
#    [230 230 230]
#    ...
#    [230 230 230]
#    [230 230 230]
#    [229 229 229]]
#
#   [[229 229 229]
#    [230 230 230]
#    [231 231 231]
#    ...
#    [231 231 231]
#    [231 231 231]
#    [231 231 231]]
#
#   [[231 231 231]
#    [232 232 232]
#    [231 231 231]
#    ...
#    [228 228 228]
#    [228 228 228]
#    [229 229 229]]]]

# %%
print (gray.shape)
# Out:
# (50, 50)

# %%
print (gray)
print (x.reshape(75,100))
clf.fit(x,y_train)
# Out:
# [[232 232 232 ... 230 230 231]
#  [232 232 232 ... 231 231 231]
#  [232 232 232 ... 233 233 233]
#  ...
#  [228 228 228 ... 231 231 230]
#  [228 228 228 ... 230 229 228]
#  [230 230 230 ... 230 229 228]]
# [[228. 228. 228. ... 233. 233. 231.]
#  [231. 231. 232. ... 232. 232. 232.]
#  [232. 230. 230. ... 229. 229. 229.]
#  ...
#  [230. 230. 230. ... 228. 228. 227.]
#  [227. 227. 229. ... 230. 229. 229.]
#  [229. 230. 230. ... 230. 230. 230.]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-3bd94d689e91> in <module>
#       1 print (gray)
#       2 print (x.reshape(75,100))
# ----> 3 clf.fit(x,y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     745                     ensure_min_features=ensure_min_features,
#     746                     warn_on_dtype=warn_on_dtype,
# --> 747                     estimator=estimator)
#     748     if multi_output:
#     749         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     563         if not allow_nd and array.ndim >= 3:
#     564             raise ValueError("Found array with dim %d. %s expected <= 2."
# --> 565                              % (array.ndim, estimator_name))
#     566         if force_all_finite:
#     567             _assert_all_finite(array,
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %%
files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec6206aa1935> in <module>
# ----> 1 files
#
# NameError: name 'files' is not defined
